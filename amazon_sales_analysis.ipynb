# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('/content/Amazon Sale Report.csv')
# Out:
# <ipython-input-2-0dc50486328f>:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/Amazon Sale Report.csv')

# %%
df
# Out:
#          index             Order ID        Date                        Status  \
# 0            0  405-8078784-5731545    04-30-22                     Cancelled
# 1            1  171-9198151-1101146    04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146    04-30-22                       Shipped
# 3            3  403-9615377-8133951    04-30-22                     Cancelled
# 4            4  407-1069790-7240320    04-30-22                       Shipped
# ...        ...                  ...         ...                           ...
# 113579  113578  408-8708951-4118730  06-11-2022                       Shipped
# 113580  113579  171-9544609-9660309  06-11-2022                       Shipped
# 113581  113580  406-0208420-3522766  06-11-2022                     Cancelled
# 113582  113581  408-9468735-1997950  06-11-2022                       Shipped
# 113583  113582  402-1724542-2028309  06-11-2022                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# 1        Merchant     Amazon.in           Standard     Shirt  3XL
# 2          Amazon     Amazon.in          Expedited     Shirt   XL
# 3        Merchant     Amazon.in           Standard   Blazzer    L
# 4          Amazon     Amazon.in          Expedited  Trousers  3XL
# ...           ...           ...                ...       ...  ...
# 113579     Amazon     Amazon.in          Expedited   Blazzer  3XL
# 113580     Amazon     Amazon.in          Expedited     Shirt   XL
# 113581     Amazon     Amazon.in          Expedited     Shirt    L
# 113582     Amazon     Amazon.in          Expedited   T-shirt    M
# 113583        NaN           NaN                NaN       NaN  NaN
#
#        Courier Status  ...  currency   Amount    ship-city     ship-state  \
# 0          On the Way  ...       INR   647.62       MUMBAI    MAHARASHTRA
# 1             Shipped  ...       INR   406.00    BENGALURU      KARNATAKA
# 2             Shipped  ...       INR   329.00  NAVI MUMBAI    MAHARASHTRA
# 3          On the Way  ...       INR   753.33   PUDUCHERRY     PUDUCHERRY
# 4             Shipped  ...       INR   574.00      CHENNAI     TAMIL NADU
# ...               ...  ...       ...      ...          ...            ...
# 113579        Shipped  ...       INR   599.00        NOIDA  UTTAR PRADESH
# 113580        Shipped  ...       INR   635.00      LUCKNOW  UTTAR PRADESH
# 113581      Unshipped  ...       INR   544.00     DURGAPUR    WEST BENGAL
# 113582        Shipped  ...       INR  1477.00    TARANAGAR      RAJASTHAN
# 113583            NaN  ...       NaN      NaN          NaN            NaN
#
#        ship-postal-code  ship-country    B2B fulfilled-by New  PendingS
# 0              400081.0            IN  False    Easy Ship NaN       NaN
# 1              560085.0            IN  False    Easy Ship NaN       NaN
# 2              410210.0            IN   True          NaN NaN       NaN
# 3              605008.0            IN  False    Easy Ship NaN       NaN
# 4              600073.0            IN  False          NaN NaN       NaN
# ...                 ...           ...    ...          ...  ..       ...
# 113579         201310.0            IN  False          NaN NaN       NaN
# 113580         226025.0            IN  False          NaN NaN       NaN
# 113581         713205.0            IN  False          NaN NaN       NaN
# 113582         331304.0            IN  False          NaN NaN       NaN
# 113583              NaN           NaN    NaN          NaN NaN       NaN
#
# [113584 rows x 21 columns]

# %%
df.shape
# Out:
# (113584, 21)

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# 0  ...       INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1  ...       INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2  ...       INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
# 3  ...       INR  753.33   PUDUCHERRY   PUDUCHERRY         605008.0
# 4  ...       INR  574.00      CHENNAI   TAMIL NADU         600073.0
#
#    ship-country    B2B fulfilled-by New  PendingS
# 0            IN  False    Easy Ship NaN       NaN
# 1            IN  False    Easy Ship NaN       NaN
# 2            IN   True          NaN NaN       NaN
# 3            IN  False    Easy Ship NaN       NaN
# 4            IN  False          NaN NaN       NaN
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#          index             Order ID        Date     Status Fulfilment  \
# 113579  113578  408-8708951-4118730  06-11-2022    Shipped     Amazon
# 113580  113579  171-9544609-9660309  06-11-2022    Shipped     Amazon
# 113581  113580  406-0208420-3522766  06-11-2022  Cancelled     Amazon
# 113582  113581  408-9468735-1997950  06-11-2022    Shipped     Amazon
# 113583  113582  402-1724542-2028309  06-11-2022    Shipped        NaN
#
#        Sales Channel ship-service-level Category Size Courier Status  ...  \
# 113579     Amazon.in          Expedited  Blazzer  3XL        Shipped  ...
# 113580     Amazon.in          Expedited    Shirt   XL        Shipped  ...
# 113581     Amazon.in          Expedited    Shirt    L      Unshipped  ...
# 113582     Amazon.in          Expedited  T-shirt    M        Shipped  ...
# 113583           NaN                NaN      NaN  NaN            NaN  ...
#
#         currency  Amount  ship-city     ship-state ship-postal-code  \
# 113579       INR   599.0      NOIDA  UTTAR PRADESH         201310.0
# 113580       INR   635.0    LUCKNOW  UTTAR PRADESH         226025.0
# 113581       INR   544.0   DURGAPUR    WEST BENGAL         713205.0
# 113582       INR  1477.0  TARANAGAR      RAJASTHAN         331304.0
# 113583       NaN     NaN        NaN            NaN              NaN
#
#         ship-country    B2B fulfilled-by New  PendingS
# 113579            IN  False          NaN NaN       NaN
# 113580            IN  False          NaN NaN       NaN
# 113581            IN  False          NaN NaN       NaN
# 113582            IN  False          NaN NaN       NaN
# 113583           NaN    NaN          NaN NaN       NaN
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113584 entries, 0 to 113583
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               113584 non-null  int64
#  1   Order ID            113584 non-null  object
#  2   Date                113584 non-null  object
#  3   Status              113584 non-null  object
#  4   Fulfilment          113583 non-null  object
#  5   Sales Channel       113583 non-null  object
#  6   ship-service-level  113583 non-null  object
#  7   Category            113583 non-null  object
#  8   Size                113583 non-null  object
#  9   Courier Status      113583 non-null  object
#  10  Qty                 113583 non-null  float64
#  11  currency            106696 non-null  object
#  12  Amount              106696 non-null  float64
#  13  ship-city           113554 non-null  object
#  14  ship-state          113554 non-null  object
#  15  ship-postal-code    113554 non-null  float64
#  16  ship-country        113554 non-null  object
#  17  B2B                 113583 non-null  object
#  18  fulfilled-by        35517 non-null   object
#  19  New                 0 non-null       float64
#  20  PendingS            0 non-null       float64
# dtypes: float64(5), int64(1), object(15)
# memory usage: 18.2+ MB

# %%
#drop blank columns

df.drop(['New','PendingS'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113584 entries, 0 to 113583
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               113584 non-null  int64
#  1   Order ID            113584 non-null  object
#  2   Date                113584 non-null  object
#  3   Status              113584 non-null  object
#  4   Fulfilment          113583 non-null  object
#  5   Sales Channel       113583 non-null  object
#  6   ship-service-level  113583 non-null  object
#  7   Category            113583 non-null  object
#  8   Size                113583 non-null  object
#  9   Courier Status      113583 non-null  object
#  10  Qty                 113583 non-null  float64
#  11  currency            106696 non-null  object
#  12  Amount              106696 non-null  float64
#  13  ship-city           113554 non-null  object
#  14  ship-state          113554 non-null  object
#  15  ship-postal-code    113554 non-null  float64
#  16  ship-country        113554 non-null  object
#  17  B2B                 113583 non-null  object
#  18  fulfilled-by        35517 non-null   object
# dtypes: float64(3), int64(1), object(15)
# memory usage: 16.5+ MB

# %%
df.isnull().sum()  #getting total null values
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                1
# Sales Channel             1
# ship-service-level        1
# Category                  1
# Size                      1
# Courier Status            1
# Qty                       1
# currency               6888
# Amount                 6888
# ship-city                30
# ship-state               30
# ship-postal-code         30
# ship-country             30
# B2B                       1
# fulfilled-by          78067
# dtype: int64

# %%
df.shape
# Out:
# (113584, 19)

# %%
df.dropna(inplace=True)    #dropping null values

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# fulfilled-by          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
# change data type

df['ship-postal-code']=df['ship-postal-code'].astype('int')

# %%
df['ship-postal-code'].dtype
# Out:
# dtype('int64')

# %%
df['Date']=pd.to_datetime (df['Date'])

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
df.rename(columns={'Qty':'Quantity'},inplace=True)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Quantity',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
#describe() method return description of the data in the DataFrame(i.e count,mean,std,min..etc)
df.describe()
# Out:
#                index      Quantity        Amount  ship-postal-code
# count   33926.000000  33926.000000  33926.000000      33926.000000
# mean    54573.949744      0.868036    643.029535     462629.110977
# std     32763.595134      0.353952    281.009090     195097.292747
# min         0.000000      0.000000      0.000000     110001.000000
# 25%     23862.250000      1.000000    453.000000     363002.000000
# 50%     58036.000000      1.000000    622.860000     500018.000000
# 75%     79991.500000      1.000000    771.000000     600042.000000
# max    113571.000000      5.000000   5495.000000     989898.000000

# %%
df.describe(include='object')
# Out:
#                    Order ID                        Status Fulfilment  \
# count                 33926                         33926      33926
# unique                31284                            11          1
# top     171-5057375-2831560  Shipped - Delivered to Buyer   Merchant
# freq                     12                         25886      33926
#
#        Sales Channel ship-service-level Category   Size Courier Status  \
# count          33926              33926    33926  33926          33926
# unique             1                  1        8     11              3
# top        Amazon.in           Standard  T-shirt      M        Shipped
# freq           33926              33926    12787   6208          28780
#
#        currency  ship-city   ship-state ship-country    B2B fulfilled-by
# count     33926      33926        33926        33926  33926        33926
# unique        1       4436           57            1      2            1
# top         INR  BENGALURU  MAHARASHTRA           IN  False    Easy Ship
# freq      33926       2525         5605        33926  33659        33926

# %%
df[['Quantity','Amount']].describe()
# Out:
#            Quantity        Amount
# count  33926.000000  33926.000000
# mean       0.868036    643.029535
# std        0.353952    281.009090
# min        0.000000      0.000000
# 25%        1.000000    453.000000
# 50%        1.000000    622.860000
# 75%        1.000000    771.000000
# max        5.000000   5495.000000

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Quantity',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
ax=sns.countplot(x='Size' ,data=df)

# %%
ax=sns.countplot(x='Size' ,data=df)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# most buys M-Size

# %%
df.groupby(['Size'], as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False)
# Out:
#     Size  Quantity
# 6      M    5406.0
# 5      L    5186.0
# 8     XL    4952.0
# 10   XXL    4055.0
# 0    3XL    3625.0
# 7      S    3502.0
# 9     XS    1948.0
# 4   Free     439.0
# 3    6XL     150.0
# 2    5XL      98.0
# 1    4XL      88.0

# %%
S_Qty=df.groupby(['Size'], as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False)

sns.barplot(x='Size',y='Quantity', data= S_Qty)
# Out:
# <Axes: xlabel='Size', ylabel='Quantity'>

# %% [markdown]
#  From above Graph you can see that most of the Qty buys M-Size in the sales

# %%
sns.countplot(data=df, x='Courier Status',hue= 'Status')
# Out:
# <Axes: xlabel='Courier Status', ylabel='count'>

# %%
plt.figure(figsize=(10,5))

ax=sns.countplot(data=df, x='Courier Status',hue= 'Status')

plt.show()

# %% [markdown]
# From above Graph the majority of the orders are shipped through the courier.

# %%
df['Size'].hist()
# Out:
# <Axes: >

# %%
df['Category'] = df['Category'].astype(str)
column_data = df['Category']
plt.figure(figsize=(10, 5))
plt.hist(column_data, bins=30, edgecolor='Black')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From above Graph you can see that most of the buyers are T-shirt

# %%
# Checking B2B Data  by using pie chart
B2B_Check = df['B2B'].value_counts()

#  Plot the pie chart
plt.pie(B2B_Check, labels=B2B_Check, autopct='%1.1f%%')
#plt.axis('equal')
plt.show()

# %%
# Checking B2B Data  by using pie chart
B2B_Check = df['B2B'].value_counts()

#  Plot the pie chart
plt.pie(B2B_Check, labels=B2B_Check.index, autopct='%1.1f%%')
#plt.axis('equal')
plt.show()

# %% [markdown]
# From above chart we can see that maximum i.e. 99.3% of buyers are retailers and 0.7% are B2B buyers

# %%
# Prepare data for scatter plot
x_data = df['Category']
y_data = df['Size']

# Plot the scatter plot
plt.scatter(x_data, y_data)
plt.xlabel('Category ')
plt.ylabel('Size')
plt.title('Scatter Plot')
plt.show()

# %%
# Plot count of cities by state
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='ship-state')
plt.xlabel('ship-state')
plt.ylabel('count')
plt.title('Distribution of State')
plt.xticks(rotation=90)
plt.show()

# %%
# top_10_States
top_10_state = df['ship-state'].value_counts().head(10)
# Plot count of cities by state
plt.figure(figsize=(12, 6))
sns.countplot(data=df[df['ship-state'].isin(top_10_state.index)], x='ship-state')
plt.xlabel('ship-state')
plt.ylabel('count')
plt.title('Distribution of  State')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  From above Graph you can see that most of the buyers are Maharashtra state

# %% [markdown]
# Conclusion
#
# The data analysis reveals that the business has a significant customer base in Maharashtra state, mainly serves retailers, fulfills orders through Amazon, experiences high demand for T-shirts, and sees M-Size as the preferred choice among buyers.
